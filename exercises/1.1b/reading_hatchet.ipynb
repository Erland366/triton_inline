# %%
import hatchet as ht

gf = ht.GraphFrame.from_caliper("/home/coder/Python_project/triton_inline/benchmark_results/1.1b/proton.hatchet")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import hatchet as ht
# ----> 3 gf = ht.GraphFrame.from_caliper("/home/coder/Python_project/triton_inline/benchmark_results/1.1b/proton.hatchet")
#
# File ~/Python_project/triton_inline/.venv/lib/python3.13/site-packages/hatchet/util/logger.py:135, in Log.loggable.<locals>.inner(*args, **kwargs)
#     133         return holder
#     134     else:
# --> 135         return function(*args, **kwargs)
#     137 # If there is a file io error when logging
#     138 # we run function as normal and abandon log
#     139 except IOError:
#
# File ~/Python_project/triton_inline/.venv/lib/python3.13/site-packages/hatchet/graphframe.py:164, in GraphFrame.from_caliper(filename_or_stream, query)
#     161 # import this lazily to avoid circular dependencies
#     162 from .readers.caliper_reader import CaliperReader
# ...
